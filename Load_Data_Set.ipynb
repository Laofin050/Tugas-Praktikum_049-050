# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:28<00:00, 31.8MB/s]
# 100% 2.29G/2.29G [00:28<00:00, 86.1MB/s]

# %%
api_token = {"username":"lauvinarivacabs","key":"62055a6785742512f9ec3cbb5c0eea5f"}
import json
import zipfile
import os
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json

# %%
import os
import zipfile

local_zip = '/content/chest-xray-pneumonia.zip' #lokasi zip
zip_ref = zipfile.ZipFile(local_zip, 'r') # file zip
zip_ref.extractall('/content/') #ekstrak zip
zip_ref.close()

# %%
test_b = "/content/chest_xray/test/NORMAL"
test_m = "/content/chest_xray/test/PNEUMONIA"
train_b = "/content/chest_xray/train/NORMAL"
train_m = "/content/chest_xray/train/PNEUMONIA"

file_test_b = os.listdir(test_b)
file_test_m = os.listdir(test_m)
file_train_b = os.listdir(train_b)
file_train_m = os.listdir(train_m)

print("NORMAL_test : " + str(len(file_test_b)))
print("PNEUMONIA_test : " + str(len(file_test_m)))
print("NORMAL_train : " + str(len(file_train_b)))
print("PNEUMONIA_train : " + str(len(file_train_m)))
# Out:
# NORMAL_test : 234
# PNEUMONIA_test : 390
# NORMAL_train : 1341
# PNEUMONIA_train : 3875

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

Normal_dir=os.path.join('/content/chest_xray/train/NORMAL')
Pneumonia_dir=os.path.join('/content/chest_xray/train/PNEUMONIA')

Normal_image = os.listdir(Normal_dir)
Pneumonia_image = os.listdir(Pneumonia_dir)

fname1 = [os.path.join(Normal_dir,fname)
        for fname in Normal_image[:4]]

fname2 = [os.path.join(Pneumonia_dir,fname)
        for fname in Pneumonia_image[:4]]

ncolu = 4
nrow = 2
fig = plt.gcf()
fig.set_size_inches(ncolu*4,nrow*4)
for i,fname in enumerate(fname1):
    sp = plt.subplot(2,4,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Normal')
    plt.imshow(img)
plt.show()

ncolu = 4
nrow = 2
fig = plt.gcf()
fig.set_size_inches(ncolu*4,nrow*4)
for i,fname in enumerate(fname2):
    sp = plt.subplot(2,4,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Pneumonia')
    plt.imshow(img)
    
plt.show()
